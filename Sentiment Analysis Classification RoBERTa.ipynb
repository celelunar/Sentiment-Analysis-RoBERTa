# %% [markdown]
# <a href="https://colab.research.google.com/github/celelunar/Sentiment-Analysis-RoBERTa/blob/main/Sentiment%20Analysis%20Classification%20RoBERTa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Diva Nabila Henryka
# <br>
# NIM: 2501975620
# <br>
#
#
# ---

# %% [markdown]
# You are a data scientist tasked with developing a sentiment
# analysis system for a hospital in Indonesia. This system aims to discern emotions from
# questionnaire responses. You have access to various datasets containing information such as
# Text and sentiment labels.

# %% [markdown]
# ### Preparation

# %% [markdown]
# #### Import libraries needed

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import CategoricalAccuracy, Precision, Recall, Precision, F1Score

from transformers import RobertaModel, TFAutoModel, AdamWeightDecay, RobertaTokenizer

import tensorflow as tf

# %% [markdown]
# #### Accessing the dataset through Google Drive
#
# I choose to store the dataset in my Google Drive to avoid the hassle of reuploading the dataset everytime the runtime gets disconnected.
# <br>
# In order to access the dataset, my Google Drive has to be mounted first, then read the dataset using:
#
# ```
# pd.read_csv("/path to file/file.csv)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data  =  pd.read_csv('/content/drive/MyDrive/Final/Emotion.csv')
data.head()
# Out:
#                                                 text    label
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %% [markdown]
# ### A. Data Exploration, Cleaning, and Preprocessing

# %% [markdown]
# #### Familiarize with the dataset
# The first step of data exploration is familiarizing ourselves with the dataset that we'll be dealing with to know the attributes, columns in this case, data shape, and type of each attributes using:
# ```
# .info()
# ```

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20000 non-null  object
#  1   label   20000 non-null  object
# dtypes: object(2)
# memory usage: 312.6+ KB

# %% [markdown]
# From the result above it can be seen that our data has 2 columns, text and sentiment label of the text, and it has 20000 entries. Thus the data shape is (20000, 2).

# %% [markdown]
# #### Checking for missing values
# Checking for missing value is a crucial step in data exploration, since incomplete data can bias the result of the model and/or reduce the accuracy of the model. To check the missing values we can use:
# ```
# .isna()
# .isnull()
# ```

# %%
print("Missing Values: ")
Na = data.isna().sum().sort_values(ascending = False)
Null = data.isnull().sum().sort_values(ascending = False)
missingData = pd.concat([Na, Null], axis = 1, keys = ['Total Na', 'Total Null'])
missingData.head()
# Out:
# Missing Values:
#        Total Na  Total Null
# text          0           0
# label         0           0

# %% [markdown]
# From the result above, it can be concluded that the data has no missing values.

# %% [markdown]
# #### Check for duplicates
# Data duplication can add the weights of sample and cause bias to the result of the model, thus it is important to check and handle it. To check duplicates, we can use:
# ```
# .duplicated()
# ```

# %%
print("Before removing duplicated data:")
data.duplicated().sum()
# Out:
# Before removing duplicated data:
# 1

# %%
df_duplicate = data[data.duplicated(keep = False)]
df_duplicate
# Out:
#                                                     text label
# 4975   i feel more adventurous willing to take risks ...   joy
# 13846  i feel more adventurous willing to take risks ...   joy

# %% [markdown]
# Since the data turned out to have duplicated rows, we can resolve it by dropping one of the duplicated rows using:
# ```
# .drop_duplicates()
# ```

# %%
data = data.drop_duplicates(keep = 'first')

print("After removing duplicated data:")
data.duplicated().sum()
# Out:
# After removing duplicated data:
# 0

# %% [markdown]
# #### Sentiment label modification
# To make it easier for the model to conduct sentiment analysis of a text, we have to change the categorical text values to a numerical values. To do so we can use:
# ```
# .apply(lambda x: [numerical value] if x == '[categorical text value]' else x)
# ```

# %%
data['label'].unique()
# Out:
# array(['sadness', 'anger', 'love', 'surprise', 'fear', 'joy'],
#       dtype=object)

# %%
def modify_label(data):
  df = data.copy()

  df['label'] = df['label'].apply(lambda x: 0 if x == 'sadness' else x)
  df['label'] = df['label'].apply(lambda x: 1 if x == 'anger' else x)
  df['label'] = df['label'].apply(lambda x: 2 if x == 'love' else x)
  df['label'] = df['label'].apply(lambda x: 3 if x == 'surprise' else x)
  df['label'] = df['label'].apply(lambda x: 4 if x == 'fear' else x)
  df['label'] = df['label'].apply(lambda x: 5 if x == 'joy' else x)

  return df

# %%
def info_data(df, name):
  sadness = df[df.label == 0].shape[0]
  anger = df[df.label == 1].shape[0]
  love = df[df.label == 2].shape[0]
  surprise = df[df.label == 3].shape[0]
  fear = df[df.label == 4].shape[0]
  joy = df[df.label == 5].shape[0]

  amount = [
      ["sadness", sadness],
      ["anger", anger],
      ["love", love],
      ["surprise", surprise],
      ["fear", fear],
      ["joy", joy]
  ]

  print(name, "dataset info:")
  print("Shape: ", df.shape)
  print("Amount per category:")
  print(tabulate(amount, headers = ["Category", "Amount"], tablefmt = "psql"))

# %%
modified_data = modify_label(data)
info_data(modified_data, "Original")
# Out:
# Original dataset info:
# Shape:  (19999, 2)
# Amount per category:
# +------------+----------+
# | Category   |   Amount |
# |------------+----------|
# | sadness    |     5797 |
# | anger      |     2709 |
# | love       |     1641 |
# | surprise   |      719 |
# | fear       |     2373 |
# | joy        |     6760 |
# +------------+----------+

# %% [markdown]
# #### Text cleaning
# Not only we have to modify the categorial text values to numerical values, we also have to standardized the format of all text inputs. Thus we have to remove all special characters, numbers, and change it into either lowercase or uppercase.

# %%
puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£',
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…',
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─',
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞',
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def text_cleaning(text):
  def clean_text(x):
    x = str(x)
    for punct in puncts:
      if punct in x:
        x = x.replace(punct, f' {punct} ')
    return x

  def clean_num(x):
    if bool(re.search(r'\d', x)):
      x = re.sub('[0-9]{5,}', '#####', x)
      x = re.sub('[0-9]{4}', '####', x)
      x = re.sub('[0-9]{3}', '###', x)
      x = re.sub('[0-9]{2}', '##', x)
    return x

  text = text.lower()
  text = clean_text(text)
  text = clean_num(text)

  return text

# %%
def preprocess(df, text_col_name):
  df[text_col_name] = df[text_col_name].apply(lambda x: text_cleaning(x))
  df[text_col_name] = df[text_col_name].fillna("_##_")

  return df

# %% [markdown]
# #### Tokenization with RoBERTa Tokenizer
# Tokenization is an essential preprocessing step in NLP pipelines, as it enables the transformation of unstructured text data into a format that can be easily fed into the neural network model using RoBERTa that will be built later on.

# %%
SEQ_LEN = 80

tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
def tokenize(df):
  input_id = []
  attention_mask = []

  for i, text in enumerate(df["text"]):
    token = tokenizer.encode_plus(text, max_length = SEQ_LEN, truncation = True, padding = 'max_length',  add_special_tokens = True, return_attention_mask = True,
                                  return_token_type_ids = False, return_tensors = 'tf')
    input_id.append(np.asarray(token["input_ids"]).reshape(SEQ_LEN,))
    attention_mask.append(np.asarray(token["attention_mask"]).reshape(SEQ_LEN,))

  return (np.asarray(input_id), np.asarray(attention_mask))

# %% [markdown]
# #### One hot encoding for the sentiment labels
# To ensure the suitability of the response variable, we have to perform one hot encoding on the labels. One hot encoding is basically a technique used to represent categorical variable as a binary vector. Though, if the dataset is bigger I'd suggest to use other techniques such as embeddings or other encoding schemes, since if one were to use one hot encoding the resulting binary vector will have a very high dimension.

# %%
def one_hot_encoding(df):
  emotion_values = set(df["label"].values)
  labels = []

  for index, row in df.iterrows():
    label = np.zeros((len(emotion_values)))
    label[row["label"]] = 1
    labels.append(label)

  return (np.asarray(labels))

# %% [markdown]
# ### B. Data Splitting (Training, Validation, Testing)

# %% [markdown]
# #### Split the data
# The next part is splitting the data into 3 parts, 70% training set, 15% validation set, and 15% testing set. To do so we can first calculate the size of training and validation set, then use the `train_test_split` function from `sklearn` library.

# %%
train, temp = train_test_split(modified_data, test_size = 0.3, shuffle = True)
val, test = train_test_split(temp, test_size = 0.5, shuffle = True)

# %%
info_data(train, "Training")
print("")
info_data(val, "Validation")
print("")
info_data(test, "Testing")
# Out:
# Training dataset info:
# Shape:  (13999, 2)
# Amount per category:
# +------------+----------+
# | Category   |   Amount |
# |------------+----------|
# | sadness    |     4144 |
# | anger      |     1871 |
# | love       |     1116 |
# | surprise   |      511 |
# | fear       |     1623 |
# | joy        |     4734 |
# +------------+----------+
#
# Validation dataset info:
# Shape:  (3000, 2)
# Amount per category:
# +------------+----------+
# | Category   |   Amount |
# |------------+----------|
# | sadness    |      828 |
# | anger      |      448 |
# | love       |      259 |
# | surprise   |      109 |
# | fear       |      356 |
# | joy        |     1000 |
# +------------+----------+
#
# Testing dataset info:
# Shape:  (3000, 2)
# Amount per category:
# +------------+----------+
# | Category   |   Amount |
# |------------+----------|
# | sadness    |      825 |
# | anger      |      390 |
# | love       |      266 |
# | surprise   |       99 |
# | fear       |      394 |
# | joy        |     1026 |
# +------------+----------+

# %% [markdown]
# #### Divide the data into X and Y
# The next step is to actually divide the data into independent and response by choosing a column and storing it in another array.

# %%
trainX = train[["text"]]
trainY = train[["label"]]

valX = val[["text"]]
valY = val[["label"]]

testX = test[["text"]]
testY = test[["label"]]

# %% [markdown]
# #### Preprocess the data
# The last step of data preparation is to actually preprocess the data by calling the functions that we've made above.

# %%
trainX = preprocess(trainX.copy(), "text")
valX = preprocess(valX.copy(), "text")

# %%
train_input_id, train_attention_mask = tokenize(trainX)
val_input_id, val_attention_mask = tokenize(valX)

# %%
trainY = one_hot_encoding(trainY)
valY = one_hot_encoding(valY)

# %% [markdown]
# ### C. RoBERTa Model
# Since the last 2 numbers of my student ID is 20 ⟶ 2 + 0 ⟶ 2, thus I'll be creating the RoBERTa model.

# %%
roberta = TFAutoModel.from_pretrained("roberta-base")
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'roberta.embeddings.position_ids', 'lm_head.dense.bias']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# #### Set callbacks for early stopping, saving, and reducing learning rate
# Since the question asks to train the model until achieving satisfactory accuracy, then we'll need callbacks which will immediately stop the model training if the validation accuracy has not improved in 10 (can be changed as you please) epochs. Also, because we want to maximize the validation accuracy, then we can use `monitor = 'val_accuracy` and `mode = max` in all three callbacks.

# %%
earlystopping = EarlyStopping(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience = 10)
checkpointer = ModelCheckpoint(monitor = 'val_accuracy', mode = 'max', filepath = "model.h5", verbose = 1, save_best_only = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience = 5, min_lr = 0.00001, factor = 0.2)
callbacks = [checkpointer, earlystopping, reduce_lr]

# %%
input_id = tf.keras.layers.Input(shape = (SEQ_LEN,), name = 'input_ids', dtype = 'int32')
mask = tf.keras.layers.Input(shape = (SEQ_LEN,), name = 'attention_mask', dtype = 'int32')

# %% [markdown]
# #### Build the model
# To build the model, we can call the `roberta` function that we've set ahead. To enhance the quality of the model I also added other layers such as `BatchNormalization()`, `Dense()`, `Activation()`, and `Dropout()`.

# %%
embeddings = roberta(input_id, attention_mask = mask)[0]
roberta_output = embeddings[:, 0, :]

X = tf.keras.layers.BatchNormalization()(roberta_output)
X = tf.keras.layers.Dense(768)(X)
X = tf.keras.layers.Activation("relu")(X)
X = tf.keras.layers.Dense(768)(X)
X = tf.keras.layers.Dropout(0.1)(X)
y = tf.keras.layers.Dense(6, activation='softmax', name='outputs')(X)

model = tf.keras.Model(inputs = [input_id, mask], outputs = y)
model.layers[2].trainable = False

optimizer = AdamWeightDecay(2e-03, beta_1 = 0.8, beta = 0.9, weight_decay_rate = 0.0001)
loss = tf.keras.losses.CategoricalCrossentropy()

metrics = [
    CategoricalAccuracy(name = 'accuracy'),
    Precision(name = 'precision'),
    Recall(name = 'recall'),
    F1Score(name = 'f1_score')
]

model.compile(optimizer = optimizer, loss = loss, metrics = metrics)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 80)]                 0         []
#
#  attention_mask (InputLayer  [(None, 80)]                 0         []
#  )
#
#  tf_roberta_model (TFRobert  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  aModel)                     ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 80, 76
#                              8),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.__operators__.getitem_3  (None, 768)                  0         ['tf_roberta_model[0][0]']
#   (SlicingOpLambda)
#
#  batch_normalization_3 (Bat  (None, 768)                  3072      ['tf.__operators__.getitem_3[0
#  chNormalization)                                                   ][0]']
#
#  dense_5 (Dense)             (None, 768)                  590592    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 768)                  0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 768)                  590592    ['activation_2[0][0]']
#
#  dropout_40 (Dropout)        (None, 768)                  0         ['dense_6[0][0]']
#
#  outputs (Dense)             (None, 6)                    4614      ['dropout_40[0][0]']
#
# ==================================================================================================
# Total params: 125834502 (480.02 MB)
# Trainable params: 1187334 (4.53 MB)
# Non-trainable params: 124647168 (475.49 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the model
# After building the model, we can train the model iteratively by using the training set and validation set to validate the model's performance. I'll be using epochs of 100, batch size of 32, and of course the callbacks that have been made to stop the epoch if the validation accurracy has not improved in 10 epochs.

# %%
history = model.fit((train_input_id, train_attention_mask), trainY, validation_data = ((val_input_id,val_attention_mask), valY), epochs = 100, batch_size = 32, callbacks = callbacks)
# Out:
# Epoch 1/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.6807 - accuracy: 0.4440 - precision: 0.5163 - recall: 0.2634 - f1_score: 0.2886
# Epoch 1: val_accuracy improved from -inf to 0.50667, saving model to model.h5
# 438/438 [==============================] - 57s 101ms/step - loss: 1.6805 - accuracy: 0.4440 - precision: 0.5162 - recall: 0.2634 - f1_score: 0.2885 - val_loss: 1.5519 - val_accuracy: 0.5067 - val_precision: 1.0000 - val_recall: 3.3333e-04 - val_f1_score: 0.2620 - lr: 0.0020
# Epoch 2/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.3437 - accuracy: 0.5038 - precision: 0.6291 - recall: 0.2976 - f1_score: 0.3510
# Epoch 2: val_accuracy improved from 0.50667 to 0.56100, saving model to model.h5
# 438/438 [==============================] - 40s 92ms/step - loss: 1.3432 - accuracy: 0.5042 - precision: 0.6294 - recall: 0.2977 - f1_score: 0.3511 - val_loss: 1.2020 - val_accuracy: 0.5610 - val_precision: 0.7415 - val_recall: 0.3050 - val_f1_score: 0.3660 - lr: 0.0020
# Epoch 3/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2980 - accuracy: 0.5244 - precision: 0.6446 - recall: 0.3194 - f1_score: 0.3666
# Epoch 3: val_accuracy improved from 0.56100 to 0.56800, saving model to model.h5
# 438/438 [==============================] - 40s 91ms/step - loss: 1.2980 - accuracy: 0.5243 - precision: 0.6446 - recall: 0.3193 - f1_score: 0.3665 - val_loss: 1.1661 - val_accuracy: 0.5680 - val_precision: 0.7614 - val_recall: 0.3117 - val_f1_score: 0.4054 - lr: 0.0020
# Epoch 4/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2710 - accuracy: 0.5267 - precision: 0.6499 - recall: 0.3278 - f1_score: 0.3775
# Epoch 4: val_accuracy improved from 0.56800 to 0.57400, saving model to model.h5
# 438/438 [==============================] - 40s 92ms/step - loss: 1.2711 - accuracy: 0.5266 - precision: 0.6498 - recall: 0.3277 - f1_score: 0.3774 - val_loss: 1.1700 - val_accuracy: 0.5740 - val_precision: 0.7955 - val_recall: 0.2840 - val_f1_score: 0.4051 - lr: 0.0020
# Epoch 5/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2511 - accuracy: 0.5312 - precision: 0.6602 - recall: 0.3416 - f1_score: 0.3926
# Epoch 5: val_accuracy improved from 0.57400 to 0.58667, saving model to model.h5
# 438/438 [==============================] - 40s 91ms/step - loss: 1.2511 - accuracy: 0.5315 - precision: 0.6603 - recall: 0.3415 - f1_score: 0.3932 - val_loss: 1.1792 - val_accuracy: 0.5867 - val_precision: 0.7817 - val_recall: 0.2363 - val_f1_score: 0.4857 - lr: 0.0020
# Epoch 6/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2454 - accuracy: 0.5360 - precision: 0.6570 - recall: 0.3405 - f1_score: 0.3924
# Epoch 6: val_accuracy did not improve from 0.58667
# 438/438 [==============================] - 39s 89ms/step - loss: 1.2457 - accuracy: 0.5359 - precision: 0.6571 - recall: 0.3406 - f1_score: 0.3923 - val_loss: 1.1559 - val_accuracy: 0.5747 - val_precision: 0.7355 - val_recall: 0.3680 - val_f1_score: 0.3889 - lr: 0.0020
# Epoch 7/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2372 - accuracy: 0.5471 - precision: 0.6646 - recall: 0.3563 - f1_score: 0.4029
# Epoch 7: val_accuracy did not improve from 0.58667
# 438/438 [==============================] - 39s 88ms/step - loss: 1.2373 - accuracy: 0.5470 - precision: 0.6648 - recall: 0.3562 - f1_score: 0.4031 - val_loss: 1.2062 - val_accuracy: 0.5717 - val_precision: 0.7600 - val_recall: 0.2037 - val_f1_score: 0.4622 - lr: 0.0020
# Epoch 8/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2267 - accuracy: 0.5503 - precision: 0.6659 - recall: 0.3668 - f1_score: 0.4164
# Epoch 8: val_accuracy did not improve from 0.58667
# 438/438 [==============================] - 39s 88ms/step - loss: 1.2271 - accuracy: 0.5503 - precision: 0.6659 - recall: 0.3667 - f1_score: 0.4168 - val_loss: 1.1518 - val_accuracy: 0.5863 - val_precision: 0.7855 - val_recall: 0.3320 - val_f1_score: 0.4410 - lr: 0.0020
# Epoch 9/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2186 - accuracy: 0.5477 - precision: 0.6650 - recall: 0.3704 - f1_score: 0.4159
# Epoch 9: val_accuracy improved from 0.58667 to 0.60067, saving model to model.h5
# 438/438 [==============================] - 40s 91ms/step - loss: 1.2186 - accuracy: 0.5478 - precision: 0.6653 - recall: 0.3706 - f1_score: 0.4158 - val_loss: 1.1124 - val_accuracy: 0.6007 - val_precision: 0.7652 - val_recall: 0.3650 - val_f1_score: 0.5040 - lr: 0.0020
# Epoch 10/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2128 - accuracy: 0.5499 - precision: 0.6684 - recall: 0.3648 - f1_score: 0.4227
# Epoch 10: val_accuracy did not improve from 0.60067
# 438/438 [==============================] - 39s 89ms/step - loss: 1.2125 - accuracy: 0.5500 - precision: 0.6687 - recall: 0.3650 - f1_score: 0.4226 - val_loss: 1.1318 - val_accuracy: 0.5913 - val_precision: 0.7592 - val_recall: 0.3383 - val_f1_score: 0.4340 - lr: 0.0020
# Epoch 11/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2220 - accuracy: 0.5498 - precision: 0.6610 - recall: 0.3671 - f1_score: 0.4185
# Epoch 11: val_accuracy did not improve from 0.60067
# 438/438 [==============================] - 39s 88ms/step - loss: 1.2222 - accuracy: 0.5496 - precision: 0.6610 - recall: 0.3670 - f1_score: 0.4183 - val_loss: 1.1937 - val_accuracy: 0.5760 - val_precision: 0.7541 - val_recall: 0.3230 - val_f1_score: 0.3996 - lr: 0.0020
# Epoch 12/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2043 - accuracy: 0.5571 - precision: 0.6750 - recall: 0.3775 - f1_score: 0.4238
# Epoch 12: val_accuracy did not improve from 0.60067
# 438/438 [==============================] - 39s 89ms/step - loss: 1.2045 - accuracy: 0.5571 - precision: 0.6751 - recall: 0.3777 - f1_score: 0.4237 - val_loss: 1.1479 - val_accuracy: 0.5723 - val_precision: 0.7289 - val_recall: 0.3800 - val_f1_score: 0.3809 - lr: 0.0020
# Epoch 13/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2077 - accuracy: 0.5540 - precision: 0.6726 - recall: 0.3759 - f1_score: 0.4270
# Epoch 13: val_accuracy did not improve from 0.60067
# 438/438 [==============================] - 39s 88ms/step - loss: 1.2085 - accuracy: 0.5536 - precision: 0.6720 - recall: 0.3757 - f1_score: 0.4266 - val_loss: 1.1208 - val_accuracy: 0.5963 - val_precision: 0.7456 - val_recall: 0.3840 - val_f1_score: 0.4497 - lr: 0.0020
# Epoch 14/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.2066 - accuracy: 0.5551 - precision: 0.6735 - recall: 0.3758 - f1_score: 0.4255
# Epoch 14: val_accuracy did not improve from 0.60067
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 438/438 [==============================] - 39s 89ms/step - loss: 1.2063 - accuracy: 0.5553 - precision: 0.6737 - recall: 0.3760 - f1_score: 0.4260 - val_loss: 1.1422 - val_accuracy: 0.5840 - val_precision: 0.7277 - val_recall: 0.3733 - val_f1_score: 0.4277 - lr: 0.0020
# Epoch 15/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.1152 - accuracy: 0.5855 - precision: 0.7049 - recall: 0.4174 - f1_score: 0.4679
# Epoch 15: val_accuracy improved from 0.60067 to 0.60333, saving model to model.h5
# 438/438 [==============================] - 40s 91ms/step - loss: 1.1147 - accuracy: 0.5858 - precision: 0.7052 - recall: 0.4175 - f1_score: 0.4681 - val_loss: 1.1039 - val_accuracy: 0.6033 - val_precision: 0.7614 - val_recall: 0.3777 - val_f1_score: 0.4463 - lr: 4.0000e-04
# Epoch 16/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0975 - accuracy: 0.5967 - precision: 0.7145 - recall: 0.4314 - f1_score: 0.4798
# Epoch 16: val_accuracy improved from 0.60333 to 0.60367, saving model to model.h5
# 438/438 [==============================] - 40s 92ms/step - loss: 1.0975 - accuracy: 0.5966 - precision: 0.7144 - recall: 0.4313 - f1_score: 0.4796 - val_loss: 1.1006 - val_accuracy: 0.6037 - val_precision: 0.7772 - val_recall: 0.3523 - val_f1_score: 0.4615 - lr: 4.0000e-04
# Epoch 17/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0819 - accuracy: 0.6032 - precision: 0.7220 - recall: 0.4407 - f1_score: 0.4958
# Epoch 17: val_accuracy improved from 0.60367 to 0.61300, saving model to model.h5
# 438/438 [==============================] - 40s 91ms/step - loss: 1.0820 - accuracy: 0.6032 - precision: 0.7219 - recall: 0.4407 - f1_score: 0.4958 - val_loss: 1.0758 - val_accuracy: 0.6130 - val_precision: 0.7690 - val_recall: 0.3907 - val_f1_score: 0.4730 - lr: 4.0000e-04
# Epoch 18/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0752 - accuracy: 0.6039 - precision: 0.7179 - recall: 0.4492 - f1_score: 0.4968
# Epoch 18: val_accuracy improved from 0.61300 to 0.61800, saving model to model.h5
# 438/438 [==============================] - 40s 92ms/step - loss: 1.0753 - accuracy: 0.6038 - precision: 0.7180 - recall: 0.4491 - f1_score: 0.4967 - val_loss: 1.0750 - val_accuracy: 0.6180 - val_precision: 0.7772 - val_recall: 0.3780 - val_f1_score: 0.4783 - lr: 4.0000e-04
# Epoch 19/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0791 - accuracy: 0.6038 - precision: 0.7154 - recall: 0.4416 - f1_score: 0.4956
# Epoch 19: val_accuracy did not improve from 0.61800
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0794 - accuracy: 0.6038 - precision: 0.7151 - recall: 0.4415 - f1_score: 0.4953 - val_loss: 1.0823 - val_accuracy: 0.6110 - val_precision: 0.7615 - val_recall: 0.3960 - val_f1_score: 0.4624 - lr: 4.0000e-04
# Epoch 20/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0688 - accuracy: 0.6076 - precision: 0.7191 - recall: 0.4507 - f1_score: 0.4992
# Epoch 20: val_accuracy did not improve from 0.61800
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0684 - accuracy: 0.6077 - precision: 0.7192 - recall: 0.4509 - f1_score: 0.4995 - val_loss: 1.0848 - val_accuracy: 0.6080 - val_precision: 0.7710 - val_recall: 0.3883 - val_f1_score: 0.4715 - lr: 4.0000e-04
# Epoch 21/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0715 - accuracy: 0.6078 - precision: 0.7191 - recall: 0.4507 - f1_score: 0.5010
# Epoch 21: val_accuracy did not improve from 0.61800
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0716 - accuracy: 0.6078 - precision: 0.7192 - recall: 0.4506 - f1_score: 0.5011 - val_loss: 1.0723 - val_accuracy: 0.6157 - val_precision: 0.7702 - val_recall: 0.3777 - val_f1_score: 0.4967 - lr: 4.0000e-04
# Epoch 22/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0489 - accuracy: 0.6123 - precision: 0.7293 - recall: 0.4595 - f1_score: 0.5087
# Epoch 22: val_accuracy improved from 0.61800 to 0.62033, saving model to model.h5
# 438/438 [==============================] - 40s 92ms/step - loss: 1.0488 - accuracy: 0.6123 - precision: 0.7292 - recall: 0.4596 - f1_score: 0.5086 - val_loss: 1.0659 - val_accuracy: 0.6203 - val_precision: 0.7763 - val_recall: 0.3783 - val_f1_score: 0.5186 - lr: 4.0000e-04
# Epoch 23/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0555 - accuracy: 0.6126 - precision: 0.7195 - recall: 0.4585 - f1_score: 0.5137
# Epoch 23: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0556 - accuracy: 0.6125 - precision: 0.7192 - recall: 0.4584 - f1_score: 0.5135 - val_loss: 1.0867 - val_accuracy: 0.6077 - val_precision: 0.7840 - val_recall: 0.3763 - val_f1_score: 0.4912 - lr: 4.0000e-04
# Epoch 24/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0587 - accuracy: 0.6065 - precision: 0.7215 - recall: 0.4506 - f1_score: 0.5033
# Epoch 24: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0587 - accuracy: 0.6064 - precision: 0.7213 - recall: 0.4506 - f1_score: 0.5032 - val_loss: 1.0882 - val_accuracy: 0.6020 - val_precision: 0.7459 - val_recall: 0.3943 - val_f1_score: 0.4809 - lr: 4.0000e-04
# Epoch 25/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0481 - accuracy: 0.6089 - precision: 0.7223 - recall: 0.4592 - f1_score: 0.5116
# Epoch 25: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0487 - accuracy: 0.6087 - precision: 0.7218 - recall: 0.4590 - f1_score: 0.5113 - val_loss: 1.0717 - val_accuracy: 0.6053 - val_precision: 0.7438 - val_recall: 0.4170 - val_f1_score: 0.4627 - lr: 4.0000e-04
# Epoch 26/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0436 - accuracy: 0.6151 - precision: 0.7262 - recall: 0.4654 - f1_score: 0.5094
# Epoch 26: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0437 - accuracy: 0.6151 - precision: 0.7263 - recall: 0.4655 - f1_score: 0.5092 - val_loss: 1.0654 - val_accuracy: 0.6043 - val_precision: 0.7487 - val_recall: 0.4220 - val_f1_score: 0.4687 - lr: 4.0000e-04
# Epoch 27/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0349 - accuracy: 0.6182 - precision: 0.7299 - recall: 0.4639 - f1_score: 0.5223
# Epoch 27: val_accuracy did not improve from 0.62033
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.000000379979611e-05.
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0351 - accuracy: 0.6181 - precision: 0.7299 - recall: 0.4638 - f1_score: 0.5220 - val_loss: 1.0730 - val_accuracy: 0.6097 - val_precision: 0.7506 - val_recall: 0.4183 - val_f1_score: 0.5017 - lr: 4.0000e-04
# Epoch 28/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0282 - accuracy: 0.6246 - precision: 0.7351 - recall: 0.4783 - f1_score: 0.5277
# Epoch 28: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0284 - accuracy: 0.6245 - precision: 0.7348 - recall: 0.4781 - f1_score: 0.5279 - val_loss: 1.0616 - val_accuracy: 0.6120 - val_precision: 0.7530 - val_recall: 0.4127 - val_f1_score: 0.4879 - lr: 8.0000e-05
# Epoch 29/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0147 - accuracy: 0.6283 - precision: 0.7357 - recall: 0.4772 - f1_score: 0.5323
# Epoch 29: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0151 - accuracy: 0.6282 - precision: 0.7355 - recall: 0.4772 - f1_score: 0.5321 - val_loss: 1.0602 - val_accuracy: 0.6133 - val_precision: 0.7567 - val_recall: 0.4157 - val_f1_score: 0.4945 - lr: 8.0000e-05
# Epoch 30/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0120 - accuracy: 0.6261 - precision: 0.7385 - recall: 0.4775 - f1_score: 0.5283
# Epoch 30: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 88ms/step - loss: 1.0116 - accuracy: 0.6261 - precision: 0.7385 - recall: 0.4776 - f1_score: 0.5283 - val_loss: 1.0593 - val_accuracy: 0.6140 - val_precision: 0.7593 - val_recall: 0.4027 - val_f1_score: 0.5038 - lr: 8.0000e-05
# Epoch 31/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0055 - accuracy: 0.6274 - precision: 0.7430 - recall: 0.4820 - f1_score: 0.5338
# Epoch 31: val_accuracy did not improve from 0.62033
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0058 - accuracy: 0.6273 - precision: 0.7429 - recall: 0.4817 - f1_score: 0.5335 - val_loss: 1.0654 - val_accuracy: 0.6083 - val_precision: 0.7488 - val_recall: 0.4113 - val_f1_score: 0.4933 - lr: 8.0000e-05
# Epoch 32/100
# 437/438 [============================>.] - ETA: 0s - loss: 1.0040 - accuracy: 0.6326 - precision: 0.7451 - recall: 0.4907 - f1_score: 0.5322
# Epoch 32: val_accuracy did not improve from 0.62033
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.6000001050997525e-05.
# 438/438 [==============================] - 39s 89ms/step - loss: 1.0036 - accuracy: 0.6328 - precision: 0.7454 - recall: 0.4908 - f1_score: 0.5323 - val_loss: 1.0688 - val_accuracy: 0.6033 - val_precision: 0.7461 - val_recall: 0.4153 - val_f1_score: 0.4844 - lr: 8.0000e-05
# Epoch 32: early stopping

# %% [markdown]
# The model stops at epoch 32 with accuracy of 63.28% and validation accuracy of 60.33%. These percentage are actually "good enough", but if we want to improve it we can modify the architecture that we've made above by adding or removing a layer or changing the hyperparameters.

# %% [markdown]
# ### D. Performance Analysis

# %% [markdown]
# #### Prepare the testing data
# To do a prediction using the model that has been made, we have to prepare the testing data first using the same method as we use for the training and validation set.

# %%
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

# %%
def testing_preparation(text):
  text = text_cleaning(text)

  token = tokenizer.encode_plus(text, max_length = 80,
                                   truncation = True, padding = 'max_length',
                                   add_special_tokens = True, return_token_type_ids = False,
                                   return_tensors = 'tf')

  return {'input_ids': tf.cast(token['input_ids'], tf.float64),
            'attention_mask': tf.cast(token['attention_mask'], tf.float64)}

# %% [markdown]
# #### Predict the testing data
# To start the prediction we can use:
# ```
# [model name].predict([testing set])
# ```

# %%
def prediction(text):
    testing_data = testing_preparation(text)
    predictions = model.predict(testing_data)[0]
    return (np.argmax(predictions))

# %%
predict = np.asarray(testX["text"].apply(lambda x: prediction(x)))
actual = np.asarray(testY["label"])
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# ...
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step

# %% [markdown]
# #### Analyze the performance
# I'll be hiring `classification_report` function from the `sklearn` library to help print out the model performance analysis using the testing data.

# %%
report = classification_report(actual, predict, digits = 4, output_dict = False, target_names = ["sadness", "anger", "love", "surprise", "fear", "joy"],)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      sadness     0.5355    0.8412    0.6544       825
#        anger     0.6605    0.3641    0.4694       390
#         love     0.6000    0.2030    0.3034       266
#     surprise     0.6154    0.1616    0.2560        99
#         fear     0.6801    0.4695    0.5556       394
#          joy     0.7084    0.7602    0.7334      1026
#
#     accuracy                         0.6237      3000
#    macro avg     0.6333    0.4666    0.4954      3000
# weighted avg     0.6382    0.6237    0.6001      3000

# %% [markdown]
# Accuracy:
# - The overall accuracy of the model is 62.37% which means that the model prediction is correct around 62% of all testing data.
#
# <br>
#
# Precision:
# - Out of all text that the model predicted to have 'sadness' as the sentiment, 53.55% of them actually categorized as 'sadness'.
# - Out of all text that the model predicted to have 'anger' as the sentiment, 66.05% of them actually categorized as 'anger'.
# - Out of all text that the model predicted to have 'love' as the sentiment, 60% of them actually categorized as 'love'.
# - Out of all text that the model predicted to have 'surprise' as the sentiment, 61.54% of them actually categorized as 'surprise'.
# - Out of all text that the model predicted to have 'fear' as the sentiment, 68.01% of them actually categorized as 'fear'.
# - Out of all text that the model predicted to have 'sadness' as the sentiment, 70.84% of them actually categorized as 'joy'.
#
# <br>
#
# Recall:
# - Out of all text that actually categorized as 'sadness', the model predicted it correctly for 84.12% of them.
# - Out of all text that actually categorized as 'anger', the model predicted it correctly for 36.41% of them.
# - Out of all text that actually categorized as 'love', the model predicted it correctly for 20.30% of them.
# - Out of all text that actually categorized as 'surprise', the model predicted it correctly for 16.16% of them.
# - Out of all text that actually categorized as 'fear', the model predicted it correctly for 46.95% of them.
# - Out of all text that actually categorized as 'joy', the model predicted it correctly for 76.02% of them.
#
# <br>
#
# F1 Score:
# - Out of all categories, the model is better at predicting 'sadness', 'fear', and 'joy' as they have F1 Score greater than 0.5.
# - The model do the best at predicting 'joy' as it has the largest F1 score at 0.73 out of all categories.
